# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2

# %%
img = cv2.imread('cat.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
width,height = 450,600
resized_nearest = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST)
resized_linear = cv2.resize(img, (width, height), interpolation=cv2.INTER_LINEAR)
resized_cubic = cv2.resize(img, (width, height), interpolation=cv2.INTER_CUBIC)
resized = {'Resized Cubic':resized_cubic,'Resized Linear':resized_linear,'Resized Nearest':resized_nearest}

# %%
m=1
for i,j in resized.items():
    plt.figure(figsize=(20,20))
    plt.subplot(3,2,m)
    plt.title("Original Image")
    plt.imshow(img)
    m+=1
    plt.subplot(3,2,m)
    plt.title(i)
    plt.imshow(j)
    m+=1
    plt.show()

# %%
cv2.imwrite('cat.png',img)
# Out:
# True

# %%
plt.imshow(cv2.imread('cat.png'))

# %%
R = img[:,:,0]
G = img[:,:,1]
B = img[:,:,2]

# %%
m=1
plt.figure(figsize=(20,20))
plt.subplot(1,3,m)
plt.title("R")
plt.imshow(R,cmap='Reds')
m+=1
plt.subplot(1,3,m)
plt.title('G')
plt.imshow(G,cmap='Greens')
m+=1

plt.subplot(1,3,m)
plt.title('B')
plt.imshow(B,cmap='Blues')
m+=1


plt.show()
