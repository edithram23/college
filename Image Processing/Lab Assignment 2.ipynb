# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2

# %%
img_input = cv2.imread('image_new.jpeg')
img_input = cv2.cvtColor(img_input,cv2.COLOR_BGR2GRAY)
img_out   = cv2.imread('Expected Output.jpg')
img_out   = cv2.cvtColor(img_out,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(15,15),frameon=False)
plt.subplot(1,2,1)
plt.imshow(img_input,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_out,cmap='gray')

# %%
plt.hist(part)
# Out:
# (array([[ 0.,  4.,  5., ...,  9., 13., 25.],
#         [ 0.,  4.,  5., ..., 14.,  6., 27.],
#         [ 0.,  4.,  5., ..., 11.,  7., 25.],
#         ...,
#         [ 0.,  0.,  8., ...,  7., 27., 24.],
#         [ 0.,  0.,  6., ...,  4., 34., 19.],
#         [ 0.,  0.,  3., ...,  8., 30., 19.]]),
#  array([ 15. ,  38.8,  62.6,  86.4, 110.2, 134. , 157.8, 181.6, 205.4,
#         229.2, 253. ]),
#  <a list of 271 BarContainer objects>)

# %%
img_input.shape
# Out:
# (174, 271)

# %%
gaussian_blur = cv2.GaussianBlur(img_input,(3, 3), 0)

# %%
part = gaussian_blur.copy()

# %%
new = []
for i in part:
    new+=[[0 if j>210 else j for j in i ]]

# %%
new=np.array(new)

# %%
plt.figure(figsize=(15,15),frameon=False)
plt.subplot(1,2,1)
plt.imshow(new,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_out,cmap='gray')
